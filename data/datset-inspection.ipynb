# %%
from datasets import load_dataset, load_from_disk, interleave_datasets
imagenet = load_dataset("imagenet-1k", cache_dir="D:\.cache\huggingface\datasets", split="train[:1%]")
# Out:
# Found cached dataset imagenet-1k (D:/.cache/huggingface/datasets/imagenet-1k/default/1.0.0/a1e9bfc56c3a7350165007d1176b15e9128fcaf9ab972147840529aed3ae52bc)

# %%
imagenet
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 12812
# })

# %%
imagenet[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=817x363>,
#  'label': 726}

# %%
imagenet[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=817x363>

# %%
imagenet[1]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x491>

# %%
imagenet[2]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
imagenet[3]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
ds = load_from_disk("./diffusion_and_real/")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 18000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 1000
#     })
#     vali: Dataset({
#         features: ['image', 'label'],
#         num_rows: 1000
#     })
# })
